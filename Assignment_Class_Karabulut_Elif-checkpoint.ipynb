# %% [markdown]
# # My Experimentation with the Deep Visualizer

# %% [markdown]
# In this _Notebook_, I am going to document all of the comment-line options I was experimenting with running visualizer scipt __visualize__, and I will present conversion times and resulting videos from my computer.

# %% [markdown]
# ## GPU Acceleration

# %%
import torch

torch.cuda.is_available()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-c009292ce65f> in <module>
# ----> 1 import torch
#       2
#       3 torch.cuda.is_available()
#
# ModuleNotFoundError: No module named 'torch'

# %% [markdown]
# ## Example Image

# %%
from IPython.display import Image
Image("img/1.png")

# %% [markdown]
# ## Example Video 1

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="burcak.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="burcak.mp4" type="video/mp4">
# </video>

# %%
from IPython.display import Image
Image("img/3.png")

# %%
from IPython.display import Image
Image("img/2.png")

# %% [markdown]
# ## Example Video 2

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="burcak2.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="burcak2.mp4" type="video/mp4">
# </video>

# %% [markdown]
# In this video, I have used much bigger number of smooth factor which gives me much smoother transition between images.

# %% [markdown]
# ## Example Video 3

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="chocolate.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="chocolate.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 4

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="coffee.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="coffee.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 5

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="fig.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="fig.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 6

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="flamingo.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="flamingo.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 7

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="halhal.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="halhal.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 8

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="ice.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="ice.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 9

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="icecream.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="icecream.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 10

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="kavinsky.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="kavinsky.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 11

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="lemon.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="lemon.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 12

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="mashed patato.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="mashed patato.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 13

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="penguin.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="penguin.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 14

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="pepper.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="pepper.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 15

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="rivers.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="rivers.mp4" type="video/mp4">
# </video>

# %% [markdown]
# ## Example Video 16

# %%
# %%HTML
# <video width="320" height="240" controls>
#   <source src="scoop.mp4" type="video/mp4">
# </video>
# Out:
# <video width="320" height="240" controls>
#   <source src="scoop.mp4" type="video/mp4">
# </video>
